# %%
#print
print('hello world')
print('my name is aziz')
# Out:
# hello world
# my name is aziz

# %%
#variables type string
name = 'Aziz'
print(name)
# Out:
# Aziz

# %%
print('hello '+name)
# Out:
# hello Aziz

# %%
#type is fuc that tell the data type
print(type(name))
# Out:
# <class 'str'>

# %%
#type string
first_name = 'aziz'
last_name = 'alq'
full_name = first_name+' '+last_name
print(full_name)
# Out:
# aziz alq

# %%
#type int
age = 21
age = age +1
print(age)
# Out:
# 22

# %%
#short cut for age = age+1
age += 1
print(age)
# Out:
# 23

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
#string and int
print('your age is:'+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-25e36557a8f4> in <module>
#       1 #string and int
# ----> 2 print('your age is:'+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#oh somting wrong to fix that we must do casting
print('your age is:'+str(age))

# %%
#float data type
height = 250.5
print(height)
#data type
print(type(height))

# %%
#String and float
print('your height is:'+height)

# %%
#again wrong why we must do casting
print('your height is:'+str(height))

# %%
#boolen data type true or false
male = True
print(male)
print(type(male))

# %%
 #String and boolen
print('male:'+str(male))

# %%
#multiple assigment
name = 'aziz'
age = 20
male = True
print(name)
print(age)
print(male)

# %%
#another way
name,age,male = 'aziz',20,True
print(name)
print(age)
print(male)

# %%
 #the same value
aziz_age = 10
ali_age = 10
saad_age = 10
print(aziz_age)
print(ali_age)
print(saad_age)

# %%
#another way
aziz_age = ali_age = saad_age =20
print(aziz_age)
print(ali_age)
print(saad_age)
# Out:
# 20
# 20
# 20

# %%
#and another way for pranting
print(aziz_age,ali_age,saad_age)
# Out:
# 20 20 20

# %%
#and also we can
print("aziz age:",aziz_age,"ali age:",ali_age,"saad age:",saad_age)
# Out:
# aziz age: 20 ali age: 20 saad age: 20
